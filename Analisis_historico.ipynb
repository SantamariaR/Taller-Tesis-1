# %% [markdown]
# #### Vemos la evolución de las variables de las galaxias del plano MZR(M>10**10)

# %%
import numpy as np
import polars as pl
import matplotlib.pyplot as plt

# %%
# Importamos los datos
path = 'data/'

df = pl.read_csv(path+'tracks_centrales_snap28.csv')

# %%
df
